# %% [markdown]
# # Final Project Instructions (NOT FINALIZED)
#
# ## Setting up the project
#
# Create a new directory on your computer called `project`. Copy this `jupyter` directory and its contents into your project directory, so that this notebook is in your directory under `project/jupyter/report.ipynb`. Then use `uv` to initialize a new library. Edit the project metadata in `pyproject.toml` with your author information and with a name and description for the project.
#
# If you want to use GitHub to track work on your project, add your files to Git and then click the Publish Branch button in the Visual Studio Code Source Control pane. MAKE SURE YOU PUBLISH TO A PRIVATE REPOSITORY, NOT PUBLIC. As you work, commit your changes and push them to your private repository. To work on another computer, clone your private repository and install it using `uv sync`.
#
# Open the copy of this notebook in your project, which should be in `jupyter/report.ipynb`, and follow the directions below.
#
# ## Completing the project
#
# Read the introduction below for an explanation of the study and main questions. See the paper (available on the *Readings and datasets* page on Canvas) for more details.
#
# Edit the README.md file in the main project directory (not the one in this directory, which just describes the dataset). Add a heading to the main README.md file called `Installation`, which explains to a user how they can install your project once they have downloaded your project directory, and a heading called `Analysis` explaining how they can run your notebook. You can assume that the user is experienced with using Visual Studio Code. Make sure that any necessary dependencies have been added to the project using `uv` so that they are automatically installed when the user installs your project using `uv`.
#
# Fill in the cells of the notebook below to answer the main questions. The instructions specify what questions to answer, but not how you should write your code to answer them. Use techniques that you have learned from the course to answer the questions. You may add as many code cells as you like in each section to answer the question. You will also need to add Markdown cells to add figure captions. Use `uv` to add any necessary dependencies. You will need to add `jupyter` as a dependency to be able to run the notebook.
#
# In the final version of your project, you must write at least two new functions that are defined in the `project` package (not in the notebook). You must import and use your two functions somewhere within this notebook to help answer the questions. This step is not required for the Project Skeleton assignment.
#
# When you are finished, create a zip file of your whole directory and upload that to Canvas.

# %% [markdown]
# # Introduction
#
# In free-recall studies, participants study a list of words and then attempt to recall them in any order they want, with the goal of recalling as many items as possible. Researchers have found evidence of *serial position effects*, where the probability of recalling a given item varies depending on what position it was studied in the list. Words tend to be easier to recall if they were presented toward the start of the list; this is called the *primacy effect*. Words also tend to be easier to recall if they were presented toward the end of the list; this is called the *recency effect*. The recency can be observed when people recall events from their life; more recent events tend to be easier to recall, all else being equal.
#
# Polyn, Erlikhman, & Kahana (2011) wanted to know how the content of the words in the list affects serial position effects. They had participants complete three kinds of recall tests. In the *uncategorized* condition, participants studied lists of 24 words each, where each word was taken from a different category. For example, they might see *BATTLESHIP*, *ROOT BEER*, *JOURNAL*, *BLUEBERRY*, *GALE*, *SWORDFISH*, etc. After studying each list, participants were asked to complete a *free recall* test where they verbally recalled as many words as they could from the list, in whatever order they wanted. In the *categorized* condition, participants studied lists of words drawn from three categories that were mixed together in the list, with 8 words from each category. For example, in a categorized list, they might see *EURO*, *STEPFATHER*, *SUBWAY*, *SISTER-IN-LAW*, *BOAT*, *RUBLE*, etc., which are words drawn from the *CURRENCIES*, *RELATIVES*, and *MODES OF TRANSPORT* categories. After studying each list, participants completed a free recall test. In the recall-by-category condition, participants studies lists drawn from three categories, like in the categorized lists. However, at the end of the list, they completed a modified free recall task, where they were asked about each category in turn. They were first asked to recall words from one category, then a second category, and finally a third category.
#
# The authors wanted to determine how recall varies based on serial position and task condition. The main question was whether they would observe *persistent recency*, where more recent items would be easier to recall even in the recall-by-category condition after participants had already recalled from one or two other categories. If they did observe persistent recency in the recall-by-category condition, this would mean that the recency effect persists even after participants have been distracted by recalling other information.
#
# ## References
# Polyn, S. M., Erlikhman, G. & Kahana, M. J. Semantic cuing and the scale insensitivity of recency and contiguity. J Exp Psychology Learn Mem Cognition 37, 766 (2011).

# %% [markdown]
# # Results

# %% [markdown]
# ## Read the data
#
# First, read the data from the `2011_Polyn_scored.csv` file. When reading in the data, you will need to specify that "n/a" values should be treated as `null`. See the README.md file in this directory for a data dictionary explaining the columns of the data file.

# %%
# your code here

# %% [markdown]
# ## Clean the data
#
# The raw data have numeric task codes, where the task is 1, 2, or 3. Look at the data dictionary in the README file and re-assign these values to a text label describing each task phase, instead of a numeric code. For task=1, use "Uncategorized". For task=2, use "Categorized". For task=3, use "Recall-by-category". Also, filter to remove any trials where `study` is `False`; this will exclude any recall attempts where the participant accidentally repeated a word or recalled a word that wasn't on the list (these words that were recalled but were not on the list are called *intrusions*).

# %%
# your code here

# %% [markdown]
# ## Compare overall recall between conditions
#
# Before looking at effects of serial position on recall, take a look at how overall recall varies by task. Calculate the mean recall for each task, separately for each subject.
#
# Make a bar plot showing mean recall in each task condition, with error bars indicating variability across subjects. Label the y-axis with "Recall probability" and label the x-axis with "Task". Write a caption for your plot in a markdown cell below the plot.
#
# Calculate a one-way repeated-measures ANOVA to examine whether there is any effect of task on overall recall accuracy. Also calculate the mean and SEM for each condition.
#
# Do there seem be overall differences in recall between the different task conditions? Report the mean and SEM for each condition and the results of the ANOVA.

# %%
# your code here

# %% [markdown]
# (Discuss your results here.)

# %% [markdown]
# ## Plot recall by serial position and task
#
# Next, calculate how recall probability varies depending on subject, serial position, and task condition.
#
# Make a figure with line plots showing how recall probability varies depending on serial position and task condition. Your plot should look similar to the top panel of Figure 1 in Polyn et al. (2011), but with error bands indicating variability across subjects. the order of the subplots should be so the Uncategorized condition is on the left, Categorized is in the center, and Recall-by-category is on the right. Label the x-axis as "Serial position" and the y-axis as "Recall probability". Set the y-axis limits to range between 0 and 1. Write a caption for your figure in a markdown cell below it.
#
# Discuss your results. Does recall appear to vary by serial position in each task condition?

# %%
# your code here

# %% [markdown]
# (Discuss your results here.)

# %% [markdown]
# ## Plot recall-by-category by serial position
#
# For the recall-by-category trials, you can think of the different categories as being sort of within separate "lists" that have their own serial position. For example, you can label the first item of each category as having a category serial position of 1, the second item from that category as position 2, and so forth. The `category_input` column indicates this position. The `period` column indicates which recall period each category was prompted. For example, a participant might have been asked to recall the *CITIES* category in period 1, followed by the *CLOTHES* category in period 2, and then the *BUILDING PARTS* category in period 3.
#
# For just the recall-by-category trials, calculate the mean recall for each combination of subject, recall period, and category input.
#
# Make a figure with line plots showing how recall varies by within-category serial position, separately for each recall period. Your plot should look similar to Figure 2 in Polyn et al. (2011), but with confidence bands that indicate variability across subjects. Label the x-axis as "Serial position" and the y-axis as "Recall probability". Set the y-axis so it varies between 0 and 1. Write a caption for your figure in a markdown cell below it.
#
# Discuss your results. Does there appear to be a recency effect in each recall period?

# %%
# your code here

# %% [markdown]
# (Discuss your results here.)

# %% [markdown]
# ## Test for a recency effect during each recall-by-category period
#
# For just the recall-by-category trials, divide category serial positions (which are in the `category_input` column) into bins (Early: position 1-3; Middle: position 4-5; Late: position 6-8). Hint: you can use the Polars [cut](https://docs.pola.rs/api/python/stable/reference/series/api/polars.Series.cut.html) method to split numeric labels into bins.
#
# Calculate the mean recall for each subject in each within-category serial position bin, separately for each recall period. Then calculate the mean and SEM for each serial position bin, separately for each recall period.
#
# Use paired t-tests to test whether the recall is significantly greater for Late positions compared to Middle positions, separately for each recall period. Hint: try using a pivot table to reorganize your data into a different shape that makes it easier to compare serial position bins.
#
# Report the results of the t-tests and the mean and SEM for the middle and late positions for each recall period. Is there evidence for a recency effect that persists after period 1? If so, does it only exist for recall period 2, or does it also appear in recall period 3?

# %%
# your code here

# %% [markdown]
# (Report your statistics and discuss your results here.)

# %% [markdown]
# # Discussion
#
# (Discuss your findings. Were there differences in recall between the uncategorized, categorized, and recall-by-category lists? Were there primacy and recency effects in each task condition? In the recall-by-category condition, was there evidence of a recency effect that persists after recall period 1?)
